# %%
#warm
import warnings
warnings.filterwarnings('ignore')

# Data manipulation
import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display propertice
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# Date
import datetime

# # Maps
# import geopandas as gpd
# import pycountry

from math import pi

# Display in Jupyter
from IPython.display import display, HTML

# %%
# Load dataset
df_fifa19 = pd.read_csv('data/data.csv')

# %%
# Show the first five rows
df_fifa19.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo    Value  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  €110.5M
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png     €77M
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  €118.5M
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png     €72M
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png    €102M
#
#     Wage  Special  Acceleration  Aggression  Agility  Balance  BallControl  \
# 0  €565K     2195            91          48       91       95           96
# 1  €405K     2228            89          63       87       70           94
# 2  €290K     2143            94          56       96       84           95
# 3  €260K     1471            57          38       60       43           42
# 4  €355K     2281            78          76       79       77           91
#
#     Body Type   CAM    CB   CDM    CF    CM  Composure Contract Valid Until  \
# 0       Messi  93+2  47+2  61+2  93+2  84+2         96                 2021
# 1  C. Ronaldo  88+3  53+3  61+3  90+3  81+3         95                 2022
# 2      Neymar  89+3  47+3  60+3  89+3  81+3         94                 2022
# 3        Lean   NaN   NaN   NaN   NaN   NaN         68                 2019
# 4      Normal  88+3  66+3  77+3  87+3  87+3         88                 2023
#
#    Crossing  Curve  Dribbling  FKAccuracy  Finishing  GKDiving  GKHandling  \
# 0        77     93         97          94         95         6          11
# 1        84     81         88          76         94         7          11
# 2        79     88         96          87         87         9           9
# 3        17     21         18          19         13        90          85
# 4        93     85         86          83         82        15          13
#
#    GKKicking  GKPositioning  GKReflexes  HeadingAccuracy  Interceptions  \
# 0         15             14           8               70             22
# 1         15             14          11               89             29
# 2         15             15          11               62             36
# 3         87             88          94               21             30
# 4          5             10          13               55             61
#
#    International Reputation  Jersey Number        Joined  Jumping   LAM    LB  \
# 0                       5.0           10.0   Jul 1, 2004       68  93+2  58+2
# 1                       5.0            7.0  Jul 10, 2018       95  88+3  61+3
# 2                       5.0           10.0   Aug 3, 2017       61  89+3  60+3
# 3                       4.0            1.0   Jul 1, 2011       67   NaN   NaN
# 4                       4.0           17.0  Aug 30, 2015       63  88+3  73+3
#
#     LCB   LCM   LDM    LF    LM    LS    LW   LWB Loaned From  LongPassing  \
# 0  47+2  84+2  61+2  93+2  90+2  88+2  92+2  63+2         NaN           87
# 1  53+3  81+3  61+3  90+3  88+3  91+3  89+3  65+3         NaN           77
# 2  47+3  81+3  60+3  89+3  88+3  84+3  89+3  65+3         NaN           78
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN         NaN           51
# 4  66+3  87+3  77+3  87+3  88+3  82+3  87+3  77+3         NaN           91
#
#    LongShots  Marking  Penalties Position  Positioning Preferred Foot   RAM  \
# 0         94       33         75       RW           94           Left  93+2
# 1         93       28         85       LW           95          Right  88+3
# 2         82       27         81      CAM           89          Right  89+3
# 3         12       15         40       GK           12          Right   NaN
# 4         91       68         79      RCM           87          Right  88+3
#
#      RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB  Reactions Real Face  \
# 0  58+2  47+2  84+2  61+2  93+2  90+2  88+2  92+2  63+2         95       Yes
# 1  61+3  53+3  81+3  61+3  90+3  88+3  91+3  89+3  65+3         96       Yes
# 2  60+3  47+3  81+3  60+3  89+3  88+3  84+3  89+3  65+3         94       Yes
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN         90       Yes
# 4  73+3  66+3  87+3  77+3  87+3  88+3  82+3  87+3  77+3         91       Yes
#
#   Release Clause    ST  ShortPassing  ShotPower  Skill Moves  SlidingTackle  \
# 0        €226.5M  88+2            90         85            4             26
# 1        €127.1M  91+3            81         95            5             23
# 2        €228.1M  84+3            84         80            5             33
# 3        €138.6M   NaN            50         31            1             13
# 4        €196.4M  82+3            92         91            4             51
#
#    SprintSpeed  Stamina  StandingTackle  Strength  Vision  Volleys  Weak Foot  \
# 0           86       72              28        59      94       86          4
# 1           91       88              31        79      82       87          4
# 2           90       81              24        49      87       84          5
# 3           58       43              21        64      68       13          3
# 4           76       90              58        75      94       82          5
#
#         Work Rate
# 0  Medium/ Medium
# 1       High/ Low
# 2    High/ Medium
# 3  Medium/ Medium
# 4      High/ High

# %%
# Show the info about dataset
df_fifa19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17790 entries, 0 to 17789
# Data columns (total 87 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                17790 non-null  int64
#  1   ID                        17790 non-null  int64
#  2   Name                      17790 non-null  object
#  3   Age                       17790 non-null  int64
#  4   Photo                     17790 non-null  object
#  5   Nationality               17790 non-null  object
#  6   Flag                      17790 non-null  object
#  7   Overall                   17790 non-null  int64
#  8   Potential                 17790 non-null  int64
#  9   Club                      17557 non-null  object
#  10  Club Logo                 17790 non-null  object
#  11  Value                     17790 non-null  object
#  12  Wage                      17790 non-null  object
#  13  Special                   17790 non-null  int64
#  14  Acceleration              17790 non-null  int64
#  15  Aggression                17790 non-null  int64
#  16  Agility                   17790 non-null  int64
#  17  Balance                   17790 non-null  int64
#  18  BallControl               17790 non-null  int64
#  19  Body Type                 17790 non-null  object
#  20  CAM                       15806 non-null  object
#  21  CB                        15806 non-null  object
#  22  CDM                       15806 non-null  object
#  23  CF                        15806 non-null  object
#  24  CM                        15806 non-null  object
#  25  Composure                 17790 non-null  int64
#  26  Contract Valid Until      15800 non-null  object
#  27  Crossing                  17790 non-null  int64
#  28  Curve                     17790 non-null  int64
#  29  Dribbling                 17790 non-null  int64
#  30  FKAccuracy                17790 non-null  int64
#  31  Finishing                 17790 non-null  int64
#  32  GKDiving                  17790 non-null  int64
#  33  GKHandling                17790 non-null  int64
#  34  GKKicking                 17790 non-null  int64
#  35  GKPositioning             17790 non-null  int64
#  36  GKReflexes                17790 non-null  int64
#  37  HeadingAccuracy           17790 non-null  int64
#  38  Interceptions             17790 non-null  int64
#  39  International Reputation  15811 non-null  float64
#  40  Jersey Number             15800 non-null  float64
#  41  Joined                    14629 non-null  object
#  42  Jumping                   17790 non-null  int64
#  43  LAM                       15806 non-null  object
#  44  LB                        15806 non-null  object
#  45  LCB                       15806 non-null  object
#  46  LCM                       15806 non-null  object
#  47  LDM                       15806 non-null  object
#  48  LF                        15806 non-null  object
#  49  LM                        15806 non-null  object
#  50  LS                        15806 non-null  object
#  51  LW                        15806 non-null  object
#  52  LWB                       15806 non-null  object
#  53  Loaned From               1258 non-null   object
#  54  LongPassing               17790 non-null  int64
#  55  LongShots                 17790 non-null  int64
#  56  Marking                   17790 non-null  int64
#  57  Penalties                 17790 non-null  int64
#  58  Position                  17778 non-null  object
#  59  Positioning               17790 non-null  int64
#  60  Preferred Foot            17790 non-null  object
#  61  RAM                       15806 non-null  object
#  62  RB                        15806 non-null  object
# BallControl                    90
# Body Type                      10
# CAM                           102
# CB                            108
# CDM                            98
# CF                            103
# CM                             91
# Composure                      84
# Contract Valid Until           37
# Crossing                       89
# Curve                          89
# Dribbling                      94
# FKAccuracy                     90
# Finishing                      93
# GKDiving                       72
# GKHandling                     71
# GKKicking                      80
# GKPositioning                  79
# GKReflexes                     76
# HeadingAccuracy                91
# Interceptions                  89
# International Reputation        5
# Jersey Number                  99
# Joined                       1621
# Jumping                        74
# LAM                           102
# LB                             97
# LCB                           108
# LCM                            91
# LDM                            98
# LF                            103
# LM                             99
# LS                             94
# LW                            104
# LWB                            95
# Loaned From                   338
# LongPassing                    85
# LongShots                      92
# Marking                        92
# Penalties                      87
# Position                       27
# Positioning                    94
# Preferred Foot                  2
# RAM                           102
# RB                             97
# RCB                           108
# RCM                            91
# RDM                            98
# RF                            103
# RM                             99
# RS                             94
# RW                            104
# RWB                            95
# Reactions                      67
# Real Face                       2
# Release Clause               1249
# ST                             94
# ShortPassing                   85
# ShotPower                      92
# Skill Moves                     5
# SlidingTackle                  88
# SprintSpeed                    85
# Stamina                        85
# StandingTackle                 90
# Strength                       74
# Vision                         84
# Volleys                        87
# Weak Foot                       5
# Work Rate                       9
# dtype: int64

# %%
# I check where there are NaN values
df_fifa19.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          233
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Acceleration                    0
# Aggression                      0
# Agility                         0
# Balance                         0
# BallControl                     0
# Body Type                       0
# CAM                          1984
# CB                           1984
# CDM                          1984
# CF                           1984
# CM                           1984
# Composure                       0
# Contract Valid Until         1990
# Crossing                        0
# Curve                           0
# Dribbling                       0
# FKAccuracy                      0
# Finishing                       0
# GKDiving                        0
# GKHandling                      0
# GKKicking                       0
# GKPositioning                   0
# GKReflexes                      0
# HeadingAccuracy                 0
# Interceptions                   0
# International Reputation     1979
# Jersey Number                1990
# Joined                       3161
# Jumping                         0
# LAM                          1984
# LB                           1984
# LCB                          1984
# LCM                          1984
# LDM                          1984
# LF                           1984
# LM                           1984
# LS                           1984
# LW                           1984
# LWB                          1984
# Loaned From                 16532
# LongPassing                     0
# LongShots                       0
# Marking                         0
# Penalties                       0
# Position                       12
# Positioning                     0
# Preferred Foot                  0
# RAM                          1984
# RB                           1984
# RCB                          1984
# RCM                          1984
# RDM                          1984
# RF                           1984
# RM                           1984
# RS                           1984
# RW                           1984
# RWB                          1984
# Reactions                       0
# Real Face                       0
# Release Clause               1498
# ST                           1984
# ShortPassing                    0
# ShotPower                       0
# Skill Moves                     0
# SlidingTackle                   0
# SprintSpeed                     0
# Stamina                         0
# StandingTackle                  0
# Strength                        0
# Vision                          0
# Volleys                         0
# Weak Foot                       0
# Work Rate                       0
# dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df_fifa19.isnull())
# Out:
# <AxesSubplot:>

# %%
# What columns are in dataset?
df_fifa19.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Acceleration', 'Aggression', 'Agility', 'Balance', 'BallControl',
#        'Body Type', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'Composure',
#        'Contract Valid Until', 'Crossing', 'Curve', 'Dribbling', 'FKAccuracy',
#        'Finishing', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning',
#        'GKReflexes', 'HeadingAccuracy', 'Interceptions',
#        'International Reputation', 'Jersey Number', 'Joined', 'Jumping', 'LAM',
#        'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Loaned From',
#        'LongPassing', 'LongShots', 'Marking', 'Penalties', 'Position',
#        'Positioning', 'Preferred Foot', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF',
#        'RM', 'RS', 'RW', 'RWB', 'Reactions', 'Real Face', 'Release Clause',
#        'ST', 'ShortPassing', 'ShotPower', 'Skill Moves', 'SlidingTackle',
#        'SprintSpeed', 'Stamina', 'StandingTackle', 'Strength', 'Vision',
#        'Volleys', 'Weak Foot', 'Work Rate'],
#       dtype='object')

# %%
chosen_columns = [
    'Name',
    'Age',
    'Nationality',
    'Overall',
    'Potential',
    'Special',
    'Acceleration',
    'Aggression',
    'Agility',
    'Balance',
    'BallControl',
    'Body Type',
    'Composure',
    'Crossing',
    'Curve',
    'Club',
    'Dribbling',
    'FKAccuracy',
    'Finishing',
    'GKDiving',
    'GKHandling',
    'GKKicking',
    'GKPositioning',
    'GKReflexes',
    'HeadingAccuracy',
    'Interceptions',
    'International Reputation',
    'Jersey Number',
    'Jumping',
    'Joined',
    'LongPassing',
    'LongShots',
    'Marking',
    'Penalties',
    'Position',
    'Positioning',
    'Preferred Foot',
    'Reactions',
    'ShortPassing',
    'ShotPower',
    'Skill Moves',
    'SlidingTackle',
    'SprintSpeed',
    'Stamina',
    'StandingTackle',
    'Strength',
    'Value',
    'Vision',
    'Volleys',
    'Wage',
    'Weak Foot',
    'Work Rate'
]

# %%
# I create DataFrame with chosen columns
df = pd.DataFrame(df_fifa19, columns = chosen_columns)

# %%
df.shape
# Out:
# (17790, 52)

# %%
# The five random rows
df.sample(5)
# Out:
#               Name  Age Nationality  Overall  Potential  Special  \
# 7407   Deng Hanwen   23    China PR       68         76     1719
# 10642      A. Ndom   22      France       65         74     1686
# 3982     J. Adéoti   29       Benin       71         71     1723
# 9769    J. Aguirre   26    Colombia       66         71      991
# 15376      L. Zigi   21       Ghana       59         73     1062
#
#        Acceleration  Aggression  Agility  Balance  BallControl Body Type  \
# 7407             82          68       78       74           72      Lean
# 10642            34          72       34       36           31    Normal
# 3982             54          52       44       34           67    Stocky
# 9769             86          57       71       82           66    Normal
# 15376            66          28       65       54           64      Lean
#
#        Composure  Crossing  Curve                            Club  Dribbling  \
# 7407          63        53     52  Guangzhou Evergrande Taobao FC         65
# 10642         48        19     22                  Stade de Reims         22
# 3982          66        50     64                      AJ Auxerre         65
# 9769          64        66     67            Atlético Bucaramanga         67
# 15376         50        27     38          FC Sochaux-Montbéliard         63
#
#        FKAccuracy  Finishing  GKDiving  GKHandling  GKKicking  GKPositioning  \
# 7407           39         58         8          11          8             13
# 10642          17         18         8           9         10              7
# 3982           76         74         9           5          7             11
# 9769           44         55        15          15         10             15
# 15376          28         62        13          10          8             10
#
#        GKReflexes  HeadingAccuracy  Interceptions  International Reputation  \
# 7407           12               54             65                       1.0
# 10642          14               77             60                       1.0
# 3982           14               68             12                       1.0
# 9769           10               45             47                       1.0
# 15376           6               56             12                       1.0
#
#        Jersey Number  Jumping        Joined  LongPassing  LongShots  Marking  \
# 7407            18.0       79  Aug 11, 2015           68         55       68
# 10642            5.0       61  Aug 12, 2015           28         19       64
# 3982             9.0       63  Aug 17, 2018           50         70       22
# 9769            33.0       75  Jul 21, 2018           53         50       43
# 15376           34.0       65  Mar 13, 2016           29         48       14
#
#        Penalties Position  Positioning Preferred Foot  Reactions  \
# 7407          63      CDM           54          Right         69
# 10642         30      RCB           21          Right         53
# 3982          64       ST           76          Right         68
# 9769          63       LM           53          Right         56
# 15376         58       ST           55          Right         46
#
#        ShortPassing  ShotPower  Skill Moves  SlidingTackle  SprintSpeed  \
# 7407             68         47            3             62           82
# 10642            41         33            2             62           33
# 3982             66         70            3             11           52
# 9769             60         63            3             50           82
# 15376            44         56            3             14           67
#
#        Stamina  StandingTackle  Strength  Value  Vision  Volleys Wage  \
# 7407        80              63        57  €1.1M      64       46  €6K
# 10642       36              66        91  €725K      25       21  €4K
# 3982        72              15        88  €1.8M      52       64  €5K
# 9769        66              52        62  €600K      61       40  €1K
# 15376       62              13        62  €280K      39       48  €1K
#
#        Weak Foot       Work Rate
# 7407           4    High/ Medium
# 10642          2  Medium/ Medium
# 3982           2       High/ Low
# 9769           2    High/ Medium
# 15376          4       High/ Low

# %%
df.describe(exclude=['O']).columns
# Out:
# Index(['Age', 'Overall', 'Potential', 'Special', 'Acceleration', 'Aggression',
#        'Agility', 'Balance', 'BallControl', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'FKAccuracy', 'Finishing', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'HeadingAccuracy',
#        'Interceptions', 'International Reputation', 'Jersey Number', 'Jumping',
#        'LongPassing', 'LongShots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'ShortPassing', 'ShotPower', 'Skill Moves',
#        'SlidingTackle', 'SprintSpeed', 'Stamina', 'StandingTackle', 'Strength',
#        'Vision', 'Volleys', 'Weak Foot'],
#       dtype='object')

# %%
plt.figure(figsize=(25,13))
sns.heatmap(df.corr(), annot = True, linewidths=.5, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                                Age   Overall  Potential   Special  \
# Age                       1.000000  0.428474  -0.285371  0.212948
# Overall                   0.428474  1.000000   0.654026  0.589087
# Potential                -0.285371  0.654026   1.000000  0.366535
# Special                   0.212948  0.589087   0.366535  1.000000
# Acceleration              0.087264  0.192692   0.115415  0.115694
# Aggression                0.173172  0.393891   0.243033  0.243789
# Agility                   0.127098  0.259031   0.148092  0.154612
# Balance                   0.043270  0.101665   0.062142  0.061525
# BallControl               0.208469  0.456581   0.279118  0.279579
# Composure                 0.319805  0.725411   0.466519  0.435101
# Crossing                  0.182545  0.391581   0.238457  0.240113
# Curve                     0.185297  0.416904   0.263533  0.254730
# Dribbling                 0.167466  0.369500   0.227408  0.227795
# FKAccuracy                0.178320  0.394141   0.248043  0.244101
# Finishing                 0.153208  0.328456   0.202959  0.202108
# GKDiving                 -0.017982 -0.021604   0.002552 -0.023381
# GKHandling               -0.017196 -0.020760   0.002199 -0.022696
# GKKicking                -0.020076 -0.025837  -0.000012 -0.026287
# GKPositioning            -0.012337 -0.014076   0.004834 -0.020143
# GKReflexes               -0.015821 -0.019561   0.002867 -0.022392
# HeadingAccuracy           0.156134  0.335229   0.200146  0.207206
# Interceptions             0.140372  0.321285   0.199316  0.196815
# International Reputation  0.142288  0.514737   0.415132  0.274458
# Jersey Number            -0.085141 -0.183301  -0.106311 -0.119428
# Jumping                   0.116649  0.258482   0.157118  0.150772
# Aggression                      0.742994  0.470210  0.299585  0.330451
# Agility                         0.126185 -0.235181  0.594514  0.623013
# Balance                         0.153569 -0.392041  0.488986  0.511867
# BallControl                     0.415152  0.087410  0.716396  0.794993
# Composure                       0.353205  0.280192  0.630778  0.591152
# Crossing                        0.428004 -0.031438  0.682413  0.689232
# Curve                           0.259805 -0.037073  0.743027  0.806461
# Dribbling                       0.298605 -0.034356  0.727888  0.809513
# FKAccuracy                      0.277507 -0.021241  0.715586  0.748787
# Finishing                      -0.036966 -0.011621  0.694574  0.881867
# GKDiving                       -0.528317 -0.110842 -0.379993 -0.591247
# GKHandling                     -0.530047 -0.109728 -0.375642 -0.588563
# GKKicking                      -0.528887 -0.110395 -0.372665 -0.585559
# GKPositioning                  -0.525539 -0.104438 -0.373930 -0.586728
# GKReflexes                     -0.529013 -0.107117 -0.379435 -0.589339
# HeadingAccuracy                 0.558750  0.484955  0.273557  0.506676
# Interceptions                   0.940614  0.357459  0.180374  0.087021
# International Reputation        0.104331  0.126409  0.308152  0.297788
# Jersey Number                  -0.150203 -0.156504 -0.052504 -0.000472
# Jumping                         0.261339  0.279558  0.057852  0.124550
# LongPassing                     0.584691  0.112226  0.697164  0.570212
# LongShots                       0.169965  0.049763  0.751566  0.867557
# Marking                         0.904612  0.333233  0.174885  0.120864
# Penalties                       0.097466  0.052619  0.630761  0.829571
# Positioning                     0.156035  0.005457  0.731632  0.847735
# Reactions                       0.257031  0.284625  0.497810  0.389803
# ShortPassing                    0.538380  0.131148  0.712094  0.698017
# ShotPower                       0.253832  0.166684  0.677041  0.832507
# Skill Moves                     0.219512 -0.030902  0.670967  0.745099
# SlidingTackle                   0.974596  0.304832  0.111206  0.034780
# SprintSpeed                     0.173425 -0.086623  0.424244  0.553854
# Stamina                         0.567860  0.261770  0.466504  0.524165
# StandingTackle                  1.000000  0.332931  0.143941  0.071516
# Strength                        0.332931  1.000000 -0.049687  0.027738
# Vision                          0.143941 -0.049687  1.000000  0.698073
# Volleys                         0.071516  0.027738  0.698073  1.000000
# Weak Foot                       0.041488 -0.009870  0.336793  0.355880
#
#                           Weak Foot
# Age                        0.085843
# Overall                    0.209717
# Potential                  0.140124
# Special                    0.135927
# Acceleration               0.259135
# Aggression                 0.131936
# Agility                    0.300831
# Balance                    0.251794
# BallControl                0.355313
# Composure                  0.275759
# Crossing                   0.308235
# Curve                      0.343487
# Dribbling                  0.350831
# FKAccuracy                 0.329546
# Finishing                  0.355553
# GKDiving                  -0.231809
# GKHandling                -0.232388
# GKKicking                 -0.229029
# GKPositioning             -0.230958
# GKReflexes                -0.232402
# HeadingAccuracy            0.182487
# Interceptions              0.051818
# International Reputation   0.128713
# Jersey Number             -0.026484
# Jumping                    0.069813
# LongPassing                0.275527
# LongShots                  0.354417
# Marking                    0.064879
# Penalties                  0.330421
# Positioning                0.345460
# Reactions                  0.197665
# ShortPassing               0.320644
# ShotPower                  0.331882
# Skill Moves                0.338713
# SlidingTackle              0.024802
# SprintSpeed                0.246557
# Stamina                    0.230597
# StandingTackle             0.041488
# Strength                  -0.009870
# Vision                     0.336793
# Volleys                    0.355880
# Weak Foot                  1.000000

# %%
sns.lmplot(x = 'Acceleration', y = 'SprintSpeed',height=4, data = df)

# %%
sns.lmplot(x = 'Interceptions', y = 'SlidingTackle',height=4, data = df)

# %%
sns.lmplot(x = 'Interceptions', y = 'StandingTackle',height=4, data = df)

# %%
sns.lmplot(x = 'Interceptions', y = 'Marking',height=4, data = df)

# %%
# Histogram: number of players's age
sns.set(style ="dark", palette="colorblind", color_codes=True)
x = df.Age
plt.figure(figsize=(12,8))
ax = sns.distplot(x, bins = 58, kde = False, color='g')
ax.set_xlabel(xlabel="Player\'s age", fontsize=16)
ax.set_ylabel(ylabel='Number of players', fontsize=16)
ax.set_title(label='Histogram of players age', fontsize=20)
plt.show()

# %%
# The five eldest players
eldest = df.sort_values('Age', ascending = False)[['Name', 'Nationality', 'Age']].head(5)

# %%
eldest.set_index('Name', inplace=True)
eldest
# Out:
#             Nationality  Age
# Name
# O. Pérez         Mexico   45
# S. Narazaki       Japan   42
# J. Villar      Paraguay   41
# C. Muñoz      Argentina   41
# B. Nivet         France   41

# %%
# The five youngest players
youngest = df.sort_values('Age', ascending = True)[['Name', 'Nationality', 'Age']].head(5)
youngest.set_index('Name', inplace=True)
youngest
# Out:
#                 Nationality  Age
# Name
# J. Olstad            Norway   16
# J. Kitolano          Norway   16
# C. Bassett    United States   16
# A. Mahlonoko   South Africa   16
# D. Adshead          England   16

# %% [markdown]
# We see that the largest number of players are 21 or 26 yaers old

# %%
# Compare six clubs in relation to age
some_clubs = ('Juventus', 'Real Madrid', 'Paris Saint-Germain', 'FC Barcelona', 'Legia Warszawa', 'Manchester United')

# %%
df[df['Club'].isin(some_clubs)]['Club'].value_counts()
# Out:
# Manchester United      33
# Real Madrid            32
# FC Barcelona           30
# Paris Saint-Germain    30
# Legia Warszawa         27
# Juventus               25
# Name: Club, dtype: int64

# %%
# Compare six clubs in relation to age
some_clubs = ('Juventus', 'Real Madrid', 'Paris Saint-Germain', 'FC Barcelona', 'Legia Warszawa', 'Manchester United')
df_club = df.loc[df['Club'].isin(some_clubs)& df['Age']]

fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax = sns.violinplot(x="Club", y="Age", data=df_club);
ax.set_title(label='Distribution of age in some clubs', fontsize=20);

# %%
df[['Name', 'Club','Joined']]
# Out:
#                     Name                           Club        Joined
# 0               L. Messi                   FC Barcelona   Jul 1, 2004
# 1      Cristiano Ronaldo                       Juventus  Jul 10, 2018
# 2              Neymar Jr            Paris Saint-Germain   Aug 3, 2017
# 3                 De Gea              Manchester United   Jul 1, 2011
# 4           K. De Bruyne                Manchester City  Aug 30, 2015
# ...                  ...                            ...           ...
# 17785          Zhou Ting               Dalian YiFang FC  Oct 17, 2015
# 17786           M. Brown                Carlisle United   May 3, 2017
# 17787        O. Björtuft                        Odds BK  Mar 19, 2018
# 17788       B. Chevreuil  La Berrichonne de Châteauroux   Jul 1, 2017
# 17789    Anwar Memet Ali            Guizhou Hengfeng FC  Feb 23, 2018
#
# [17790 rows x 3 columns]

# %%
now = datetime.datetime.now()
df['Join_year'] = df.Joined.dropna().map(lambda x: x.split(',')[1].split(' ')[1])

# %%
df['Join_year'].isnull().sum()
# Out:
# 3161

# %%
df['Years_of_member'] = (df.Join_year.dropna().map(lambda x: now.year - int(x))).astype('int').dropna()

# %%
df['Years_of_member'].head()
# Out:
# 0    17.0
# 1     3.0
# 2     4.0
# 3    10.0
# 4     6.0
# Name: Years_of_member, dtype: float64

# %%
membership = df[['Name', 'Club', 'Years_of_member']].sort_values(by = 'Years_of_member', ascending = False).dropna().head()
membership.set_index('Name', inplace=True)
membership
# Out:
#                            Club  Years_of_member
# Name
# B. Clarke     Charlton Athletic             23.0
# P. Funk               VfR Aalen             23.0
# Yang Jiawei   Jiangsu Suning FC             22.0
# O. Bailey       Birmingham City             21.0
# R. Mphahlele      Kaizer Chiefs             20.0

# %%
# The oldest team
df.groupby(['Club'])['Age'].sum().sort_values(ascending = False).head(5)
# Out:
# Club
# Cardiff City      863
# Villarreal CF     851
# Frosinone         843
# Chelsea           832
# MKE Ankaragücü    829
# Name: Age, dtype: int64

# %%
# The youngest team
df.groupby(['Club'])['Age'].sum().sort_values(ascending = True).head(5)
# Out:
# Club
# Bray Wanderers    375
# Limerick FC       404
# Sligo Rovers      417
# Derry City        440
# Dalkurd FF        484
# Name: Age, dtype: int64

# %%
# Out:
# Name                           0
# Age                            0
# Nationality                    0
# Overall                        0
# Potential                      0
# Special                        0
# Acceleration                   0
# Aggression                     0
# Agility                        0
# Balance                        0
# BallControl                    0
# Body Type                      0
# Composure                      0
# Crossing                       0
# Curve                          0
# Club                         233
# Dribbling                      0
# FKAccuracy                     0
# Finishing                      0
# GKDiving                       0
# GKHandling                     0
# GKKicking                      0
# GKPositioning                  0
# GKReflexes                     0
# HeadingAccuracy                0
# Interceptions                  0
# International Reputation    1979
# Jersey Number               1990
# Jumping                        0
# Joined                      3161
# LongPassing                    0
# LongShots                      0
# Marking                        0
# Penalties                      0
# Position                      12
# Positioning                    0
# Preferred Foot                 0
# Reactions                      0
# ShortPassing                   0
# ShotPower                      0
# Skill Moves                    0
# SlidingTackle                  0
# SprintSpeed                    0
# Stamina                        0
# StandingTackle                 0
# Strength                       0
# Value                          0
# Vision                         0
# Volleys                        0
# Wage                           0
# Weak Foot                      0
# Work Rate                      0
# Join_year                   3161
# Years_of_member             3161
# dtype: int64

# %%
# The clubs and their players overalls
plt.figure(figsize=(12,8))
df_club = df.loc[df['Club'].isin(some_clubs) & df['Age'] & df['Overall'] ]
print(len(df_club))
sns.barplot(x=df_club['Club'], y=df_club['Overall'], palette="rocket");
plt.title('Distribution overall in several clubs')
# Out:
# 46
# Text(0.5, 1.0, 'Distribution overall in several clubs')

# %%
# All of position
plt.figure(figsize=(16,8))
sns.countplot(x = 'Position', data = df, palette = 'hls');
plt.title('Count of players on the position', fontsize=20);

# %%
df.iloc[df.groupby(df['Position'])['Overall'].idxmax()][['Name', 'Position']]
# Out:
#                   Name Position
# 2            Neymar Jr      CAM
# 43           S. Umtiti       CB
# 20     Sergio Busquets      CDM
# 60     Roberto Firmino       CF
# 66           T. Müller       CM
# 3               De Gea       GK
# 468            E. Dier      LAM
# 35             Marcelo       LB
# 8         Sergio Ramos      LCB
# 12            T. Kroos      LCM
# 92              Parejo      LDM
# 263         C. Bakambu       LF
# 34       P. Aubameyang       LM
# 29          L. Insigne       LS
# 1    Cristiano Ronaldo       LW
# 590         I. Marcone      LWB
# 175        L. Goretzka      RAM
# 69          A. Sánchez       RB
# 39        Thiago Silva      RCB
# 4         K. De Bruyne      RCM
# 61           R. Varane      RDM
# 515           Fabricio       RF
# 32          C. Eriksen       RM
# 18        A. Griezmann       RS
# 0             L. Messi       RW
# 610          S. Haller      RWB
# 7            L. Suárez       ST

# %%
player_features = (
    'Acceleration', 'Aggression', 'Agility', 
    'Balance', 'BallControl', 'Composure', 
    'Crossing', 'Dribbling', 'FKAccuracy', 
    'Finishing', 'GKDiving', 'GKHandling', 
    'GKKicking', 'GKPositioning', 'GKReflexes', 
    'HeadingAccuracy', 'Interceptions', 'Jumping', 
    'LongPassing', 'LongShots', 'Marking', 'Penalties'
)

# %%
# Top three features per position
for i, val in df.groupby(df['Position'])[player_features].mean().iterrows():
    print('Position {}: {}, {}, {}'.format(i, *tuple(val.nlargest(3).index)))
# Out:
# Position CAM: Balance, Agility, Acceleration
# Position CB: Jumping, Aggression, HeadingAccuracy
# Position CDM: Aggression, Jumping, Balance
# Position CF: Agility, Balance, Acceleration
# Position CM: Balance, Agility, Acceleration
# Position GK: GKReflexes, GKDiving, GKPositioning
# Position LAM: Agility, Balance, BallControl
# Position LB: Acceleration, Balance, Agility
# Position LCB: Jumping, Aggression, HeadingAccuracy
# Position LCM: Balance, Agility, BallControl
# Position LDM: BallControl, Aggression, LongPassing
# Position LF: Agility, Balance, Acceleration
# Position LM: Acceleration, Agility, Balance
# Position LS: Acceleration, Jumping, Agility
# Position LW: Acceleration, Agility, Balance
# Position LWB: Acceleration, Agility, Balance
# Position RAM: Agility, Balance, BallControl
# Position RB: Acceleration, Balance, Jumping
# Position RCB: Jumping, Aggression, HeadingAccuracy
# Position RCM: Balance, Agility, BallControl
# Position RDM: Aggression, Jumping, Balance
# Position RF: Agility, Acceleration, Balance
# Position RM: Acceleration, Agility, Balance
# Position RS: Acceleration, Jumping, Finishing
# Position RW: Acceleration, Agility, Balance
# Position RWB: Acceleration, Balance, Agility
# Position ST: Acceleration, Jumping, Finishing

# %%
# Top 5 left-footed players
df[df['Preferred Foot'] == 'Left'][['Name','Overall']].head()
# Out:
#             Name  Overall
# 0       L. Messi       94
# 10   T. Courtois       90
# 16     P. Dybala       89
# 18  A. Griezmann       89
# 23   David Silva       89

# %%
# Top 5 right-footed players
df[df['Preferred Foot'] == 'Right'][['Name','Overall']].head()
# Out:
#                 Name  Overall
# 1  Cristiano Ronaldo       94
# 2          Neymar Jr       92
# 3             De Gea       91
# 4       K. De Bruyne       91
# 5          E. Hazard       91

# %%
# Better is left-footed or rigth-footed players?
sns.lmplot(x = 'BallControl', y = 'Dribbling', data = df,col = 'Preferred Foot');

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  Special  \
# 0           L. Messi   31   Argentina       94         94     2195
# 1  Cristiano Ronaldo   33    Portugal       94         94     2228
# 2          Neymar Jr   26      Brazil       92         93     2143
# 3             De Gea   27       Spain       91         93     1471
# 4       K. De Bruyne   27     Belgium       91         92     2281
#
#    Acceleration  Aggression  Agility  Balance  BallControl   Body Type  \
# 0            91          48       91       95           96       Messi
# 1            89          63       87       70           94  C. Ronaldo
# 2            94          56       96       84           95      Neymar
# 3            57          38       60       43           42        Lean
# 4            78          76       79       77           91      Normal
#
#    Composure  Crossing  Curve                 Club  Dribbling  FKAccuracy  \
# 0         96        77     93         FC Barcelona         97          94
# 1         95        84     81             Juventus         88          76
# 2         94        79     88  Paris Saint-Germain         96          87
# 3         68        17     21    Manchester United         18          19
# 4         88        93     85      Manchester City         86          83
#
#    Finishing  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0         95         6          11         15             14           8
# 1         94         7          11         15             14          11
# 2         87         9           9         15             15          11
# 3         13        90          85         87             88          94
# 4         82        15          13          5             10          13
#
#    HeadingAccuracy  Interceptions  International Reputation  Jersey Number  \
# 0               70             22                       5.0           10.0
# 1               89             29                       5.0            7.0
# 2               62             36                       5.0           10.0
# 3               21             30                       4.0            1.0
# 4               55             61                       4.0           17.0
#
#    Jumping        Joined  LongPassing  LongShots  Marking  Penalties Position  \
# 0       68   Jul 1, 2004           87         94       33         75       RW
# 1       95  Jul 10, 2018           77         93       28         85       LW
# 2       61   Aug 3, 2017           78         82       27         81      CAM
# 3       67   Jul 1, 2011           51         12       15         40       GK
# 4       63  Aug 30, 2015           91         91       68         79      RCM
#
#    Positioning Preferred Foot  Reactions  ShortPassing  ShotPower  \
# 0           94           Left         95            90         85
# 1           95          Right         96            81         95
# 2           89          Right         94            84         80
# 3           12          Right         90            50         31
# 4           87          Right         91            92         91
#
#    Skill Moves  SlidingTackle  SprintSpeed  Stamina  StandingTackle  Strength  \
# 0            4             26           86       72              28        59
# 1            5             23           91       88              31        79
# 2            5             33           90       81              24        49
# 3            1             13           58       43              21        64
# 4            4             51           76       90              58        75
#
#      Value  Vision  Volleys   Wage  Weak Foot       Work Rate Join_year  \
# 0  €110.5M      94       86  €565K          4  Medium/ Medium      2004
# 1     €77M      82       87  €405K          4       High/ Low      2018
# 2  €118.5M      87       84  €290K          5    High/ Medium      2017
# 3     €72M      68       13  €260K          3  Medium/ Medium      2011
# 4    €102M      94       82  €355K          5      High/ High      2015
#
#    Years_of_member
# 0             17.0
# 1              3.0
# 2              4.0
# 3             10.0
# 4              6.0

# %%
# The clubs, where have players mainly from one country
clubs_coherency = pd.Series()
for club, players in df.groupby(['Club'])['Nationality'].count().items():
    coherency = df[df['Club'] == club].groupby(['Nationality'])['Club'].count().max() / players * 100
    clubs_coherency[club] = coherency
all_clubs_coherency = pd.DataFrame(clubs_coherency.sort_values(ascending = False) , columns=['percent'])

# %%
all_clubs_coherency[all_clubs_coherency['percent'] ==100]
# Out:
#                            percent
# Padova                       100.0
# Vitória                      100.0
# Ceará Sporting Club          100.0
# Sport Club do Recife         100.0
# Bahia                        100.0
# Ranheim Fotball              100.0
# CA Osasuna                   100.0
# Atlético Paranaense          100.0
# Grêmio                       100.0
# Atlético Mineiro             100.0
# Guadalajara                  100.0
# Bray Wanderers               100.0
# Botafogo                     100.0
# Fluminense                   100.0
# América FC (Minas Gerais)    100.0
# Internacional                100.0
# Paraná                       100.0
# Cruzeiro                     100.0
# Santos                       100.0
# Cittadella                   100.0
# Sangju Sangmu FC             100.0
# Chapecoense                  100.0

# %%
# The clubs with largest number of different countries
pd.DataFrame(df.groupby(['Club'])['Nationality'].nunique().sort_values(ascending = False)).head()
# Out:
#                         Nationality
# Club
# Brighton & Hove Albion           21
# Fulham                           19
# Udinese                          18
# Napoli                           18
# Empoli                           18

# %%
# The clubs with the smallest number of foreigners players
pd.DataFrame(df.groupby(['Club'])['Nationality'].nunique().sort_values()).head()
# Out:
#                      Nationality
# Club
# Atlético Paranaense            1
# CA Osasuna                     1
# Bahia                          1
# Guadalajara                    1
# Chapecoense                    1

# %%
# Relation dribbling and crossing with respected finishing of players
plt.figure(figsize=(18,10))
sns.scatterplot(x='Crossing', y='Dribbling',hue='Finishing',data=df)
plt.title('Relation dribbling and crossing with respected finishing of players', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Relation dribbling and crossing with respected finishing of players')

# %%
# Relation stamina and age with respected sprint speed of players
plt.figure(figsize=(18,10))
sns.scatterplot(x='Age', y='Stamina',hue='SprintSpeed',palette='coolwarm',data=df)
plt.title(label='Relation stamina and age with respected sprint speed of players', fontsize=20);
